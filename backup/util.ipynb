# %%
# %%writefile utility.py
def province_to_short(province):
    if province == "广东":
        return "GD"
    elif province == "天津":
        return "TJ"
    elif province == "山东":
        return "SD"
    elif province == "辽宁":
        return "LN"
    elif province == "江苏":
        return "JS"
    elif province == "黑龙江":
        return "HLJ"
    elif province == "吉林":
        return "JL"
    elif province == "福建":
        return "HLJ"
    elif province == "安徽":
        return "JL"
    elif province == '北京': 
        return 'BJ' 
    elif province == '湖南': 
        return 'HN' 
    elif province == '上海': 
        return 'SH' 
    elif province == '重庆': 
        return 'CQ' 
    elif province == '山西': 
        return 'SX' 
    elif province == '四川': 
        return 'SC' 
    elif province == '江西': 
        return 'JX' 
    elif province == '浙江': 
        return 'ZJ' 
    elif province == '湖北': 
        return 'HUB' 
    elif province == '河北': 
        return 'HEB' 
    elif province == '陕西': 
        return 'XX' 
    elif province == '广西': 
        return 'GX' 
    elif province == '内蒙古': 
        return 'NMG' 
    elif province == '云南': 
        return 'YN' 
    elif province == '宁夏': 
        return 'LX' 
    elif province == '甘肃': 
        return 'GS' 
    elif province == '河南': 
        return 'HEN' 
    elif province == 'GERMANY': 
        return 'HLJ' 
    elif province == 'ITALY': 
        return 'HLJ' 
    elif province == 'TAIWAN': 
        return 'HLJ' 
    elif province == 'SINGAPORE': 
        return 'HLJ' 
    elif province == '香港': 
        return 'HK'
# Out:
# Writing utility.py

# %%
for i in ['广东', '天津', '山东', '辽宁', '江苏', '黑龙江', '吉林', '福建', '安徽', '北京', '湖南',
       '上海', '重庆', '山西', '四川', '江西', '浙江', '湖北', '河北', '陕西', '广西', '内蒙古',
       '云南', '宁夏', '甘肃', '河南', 'GERMANY', 'ITALY', 'TAIWAN', 'SINGAPORE',
       '香港']:
    print("elif province == '%s': \n    return 'HLJ' "%i)
# Out:
# elif province == '广东':
#     return 'HLJ'
# elif province == '天津':
#     return 'HLJ'
# elif province == '山东':
#     return 'HLJ'
# elif province == '辽宁':
#     return 'HLJ'
# elif province == '江苏':
#     return 'HLJ'
# elif province == '黑龙江':
#     return 'HLJ'
# elif province == '吉林':
#     return 'HLJ'
# elif province == '福建':
#     return 'HLJ'
# elif province == '安徽':
#     return 'HLJ'
# elif province == '北京':
#     return 'HLJ'
# elif province == '湖南':
#     return 'HLJ'
# elif province == '上海':
#     return 'HLJ'
# elif province == '重庆':
#     return 'HLJ'
# elif province == '山西':
#     return 'HLJ'
# elif province == '四川':
#     return 'HLJ'
# elif province == '江西':
#     return 'HLJ'
# elif province == '浙江':
#     return 'HLJ'
# elif province == '湖北':
#     return 'HLJ'
# elif province == '河北':
#     return 'HLJ'
# elif province == '陕西':
#     return 'HLJ'
# elif province == '广西':
#     return 'HLJ'
# elif province == '内蒙古':
#     return 'HLJ'
# elif province == '云南':
# ...
